# %% [markdown]
# <a href="https://colab.research.google.com/github/Jorgechap/Computer-Vision/blob/master/indices2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import rioxarray as rxr
import geopandas as gpd
import earthpy as et
import earthpy.spatial as es
import earthpy.plot as ep

# %% [markdown]
# Esto mostró la imagen del arco iris. Para convertir a una matriz numpy, es tan simple como:

# %%
ndvi = os.path.join("/content/ndvipiñasentinel.tif")

ndvi  = rxr.open_rasterio(ndvi)
print(ndvi.shape)
# Out:
# (1, 82, 44)

# %% [markdown]
# Calculo de NDVI

# %%
ep.plot_bands(ndvi,
              cmap='PiYG',
              scale=False,
              vmin=-1, vmax=1,
              title="Indice NDVI\n Tauramena 24 11 2021")
plt.show()

# %% [markdown]
# Ver distribución de valores NDVI
# Usando un histograma, puede ver la distribución de valores de píxeles en su salida NDVI.

# %%
ep.hist(naip_ndvi.values,
        figsize=(12, 6),
        title=["NDVI: Distribution of pixels\n NAIP 2015 Cold Springs fire site"])

plt.show()

# %%
type(naip_ndvi), naip_ndvi.dtype
# Out:
# (xarray.core.dataarray.DataArray, dtype('float64'))
